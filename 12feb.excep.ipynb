# %%
#Q1. What is Exception in python? Write the difference between Exception SyntaxErrors?

# %%
import logging

# %%
logging.basicConfig(filename= "exp.er" , level= logging.DEBUG)

# %%
"""Exception is the base class for all exceptions.exceptions are raised when some internal events occur which changes the normal flow of program."""
# Out:
# 'Exception is the base class for all exceptions.exceptions are raised when some internal events occur which changes the normal flow of program.'

# %%
#with logging module
logging.info("Exception is the base class for all exceptions.exceptions are raised when some internal events occur which changes the normal flow of program. ")

# %%
logging.error("SyntaxErrors:- SyntaxErrors are mistakes in the source code,such as Spelling and punctuation errors,incorrectlabels,and so on,which cause an error message to be generated by the compiler.Errors are the problems in a program due to which the program will stop the execution.Exceptions:-Even if a statement or expression is syntactically correct, it may cause an error when an attempt is made to execute it. Errors detected during execution are called exceptions and are not unconditionally fatal")

# %%
"""#SyntaxErrors:- SyntaxErrors are mistakes in the source code,such as Spelling and punctuation errors,incorrectlabels,and so on,which cause an error message to be generated by the compiler.Errors are the problems in a program due to which the program will stop the execution.
###Exceptions:-Even if a statement or expression is syntactically correct, it may cause an error when an attempt is made to execute it. Errors detected during execution are called exceptions and are not unconditionally fatal: """
# Out:
# '#SyntaxErrors:- SyntaxErrors are mistakes in the source code,such as Spelling and punctuation errors,incorrectlabels,and so on,which cause an error message to be generated by the compiler.Errors are the problems in a program due to which the program will stop the execution.\n\n###Exceptions:-Even if a statement or expression is syntactically correct, it may cause an error when an attempt is made to execute it. Errors detected during execution are called exceptions and are not unconditionally fatal: '

# %%
#Q2. What happens when an exception is not handled? Explain with an example?

# %%
"""the runtime system will abort the program (i.e. crash) and an exception message will print to the console that caused the exception will not get executed."""
# Out:
# 'the runtime system will abort the program (i.e. crash) and an exception message will print to the console that caused the exception will not get executed.'

# %%
#with logging module
logging.info("the runtime system will abort the program (i.e. crash) and an exception message will print to the console that caused the exception will not get executed.")

# %%
#example of Exeption
import samidha
#This gave me error because there is No module named a 'samidha' hence
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[23], line 2
#       1 #example of Exeption
# ----> 2 import samidha
#
# ModuleNotFoundError: No module named 'samidha'

# %%
try:
    import samidha
except ModuleNotFoundError as a :
    print(a)
# Out:
# No module named 'samidha'

# %%
#Q3. Which Python statements are used to catch and handled by exceptions?

# %%
# try and except block

# %%
try:
    "samidha".test()
except Exception as e:
    print(e)
# Out:
# 'str' object has no attribute 'test'

# %%
#Q4 expain with example
#try and else
#finally
#raise

# %%
#try and else= try block is not giving problem hence executed and hence else too.
#because try successfully work  except will not get executed
try:
  print("try block will executed")
except:
  print("except block will not show msg")
else:
  print("else executed because try successfully work ")
# Out:
# try block will executed
# else executed because try successfully work

# %%
#finally = will get executedin any situation
try:
    a= 10/0
except ZeroDivisionError as z:
    print("this will executed")
finally :
    print("will get executed in any situation")
# Out:
# this will executed
# will get executed in any situation

# %%
#raise= x is less than 0  hence it raise the exepton error
x = -1

if x < 0:
  raise Exception("Sorry, no numbers below zero")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[60], line 5
#       2 x = -1
#       4 if x < 0:
# ----> 5   raise Exception("Sorry, no numbers below zero")
#
# Exception: Sorry, no numbers below zero

# %%
x = "hello"

if not type(x) is int:
  raise TypeError("Only integers are allowed")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[61], line 4
#       1 x = "hello"
#       3 if not type(x) is int:
# ----> 4   raise TypeError("Only integers are allowed")
#
# TypeError: Only integers are allowed

# %%
"""Q5. What are Custom Exceptions in python? Why do we need Custom Exceptions? Explain with an exmple"""
# Out:
# 'Q5. What are Custom Exceptions in python? Why do we need Custom Exceptions? Explain with an exmple'

# %%
"""we can define custom exceptions by creating a new class that is derived from the built-in Exception class"""
# Out:
# 'we can define custom exceptions by creating a new class that is derived from the built-in Exception class'

# %%
class InvalidAgeException(Exception):
    "Raised when the input value is less than 18"
    pass

#you need to guess this number
number = 18

try:
    input_num = int(input("Enter a number: "))
    if input_num < number:
        raise InvalidAgeException
    else:
        print("Eligible to Vote")
        
except InvalidAgeException:
    print("Exception occurred: Invalid Age")
# Out:
# Enter a number:  12
# Exception occurred: Invalid Age

# %%
class bankac(Exception): 
    pass
def __init__(self, msg):
    self.msg = msg
    
    
def checkbalance(money):
    if balance <100:
        raise bankac("you can't withdraw money")
    elif balance > 5000:
        raise bankac("save money")
    else :
        print("you have your money")

# %%
try:
    money = int(input("enter your amount"))
    bankac(money)
except bankac as a:
        print(a)
# Out:
# enter your amount 234

# %%
logging.info(" Python, we can define custom exceptions by creating a new class that is derived from the built-in Exception class.")

# %%
# Python, we can define custom exceptions by creating a new class that is derived from the built-in Exception class.

# %%
#Q6. Create custom exception class Use this class to handle an exception.

# %%
class customexception(Exception):
    pass
class dobexception(customexception):
    pass

# %%
year= int(input("enter your age"))
age = 2023 - year
try:
    if age <=30 & age > 20:
        print("the age is valid")
    else:
        raise dobexception
except dobexception:
    print("age is invalid")
# Out:
# enter your age 43
# age is invalid
